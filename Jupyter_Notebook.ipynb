# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rahul Agrawal**
# I want to be a Data Scientist

# %% [markdown]
# _I am interested in data science because it allows me to combine my analytical and technical skills with my curiosity and desire to understand complex systems and solve challenging problems. Data science also offers a wide range of career opportunities and the opportunity to make a positive impact in various industries._

# %% [markdown]
# ### This code will display the even or odd number ###

# %%
if(5%2==0):
    print("5 is even number")

else:
    print("5 is odd number")

# %% [markdown]
# [Coursera]{https://www.coursera.org/}
# * Data Science
# * Software Engineering
# * Ethical Hacker
# >Tools for Data Science
